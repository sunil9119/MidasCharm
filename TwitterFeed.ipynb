# %%
from textblob import TextBlob
import tweepy

# %%
auth = tweepy.OAuthHandler(consumer_Key, consumer_secret)
auth.set_access_token(access_Token, access_token_secret)
api = tweepy.API(auth)

query='bitcoin OR crypto'
user_tweets = api.search(q=query)
#user_tweets = api.user_timeline('naval')

#for status in tweepy.Cursor(api.user_timeline('naval')).items():
#    # process status here
#    process_status(status)

for tweet in user_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# RT @naval: "Technology doesn’t change what people want in the world, it just removes the use of violence to get there." https://t.co/4T4aH8…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @fintech_Innov: Creating your personal bitcoin vault https://t.co/KW8iPEosS9 #fintech #startup via @naval
# Sentiment(polarity=0.0, subjectivity=0.3)
# RT @zaoyang: @naval @eladgil @CarlotaPrzPerez 52/ in conclusion, central bank of bitcoin leading to the investment bank of Etherum leading…
# Sentiment(polarity=0.0, subjectivity=0.25)
# RT @zaoyang: @naval @eladgil @CarlotaPrzPerez 48/ what if it's internet 2.0 mediating trust. In that case, both understanding crypto, tradi…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @zaoyang: @naval @eladgil 34/ the monetary system is being invented in real time and it's no accident that many minutes of central banks…
# Sentiment(polarity=0.2333333333333333, subjectivity=0.35000000000000003)
# RT @naval: The well-articulated bull case that crypto ICOs are already in the process of replacing venture capital. Worth reading all fifty…
# Sentiment(polarity=0.3, subjectivity=0.1)
# RT @naval: Be careful out there, folks. The scams against crypto people are becoming extremely sophisticated and personalized. Trust nothin…
# Sentiment(polarity=0.2833333333333333, subjectivity=0.9500000000000001)
# @naval @pomomoh Oh I know in the end I am like anyone a  nobody but oh yes do I feel special in the crypto sphere w… https://t.co/d6qfJYyxoD
# Sentiment(polarity=0.35714285714285715, subjectivity=0.5714285714285714)
# @naval assimilating ham radio data modes with bitcoin blows my small mind. Venn diagram overlaps: networks, encryption, strange folk etc
# Sentiment(polarity=-0.15, subjectivity=0.275)
# RT @m6xjw: @naval Ham Radio data modes (like PSK31) and DMR (in all its forms) represent an alternate, secure network and untapped conduit…
# Sentiment(polarity=0.2, subjectivity=0.3)
# @naval Ham Radio data modes (like PSK31) and DMR (in all its forms) represent an alternate, secure network and untapped conduit for bitcoin
# Sentiment(polarity=0.2, subjectivity=0.3)
# RT @naval: Be careful out there, folks. The scams against crypto people are becoming extremely sophisticated and personalized. Trust nothin…
# Sentiment(polarity=0.2833333333333333, subjectivity=0.9500000000000001)
# RT @naval: Be careful out there, folks. The scams against crypto people are becoming extremely sophisticated and personalized. Trust nothin…
# Sentiment(polarity=0.2833333333333333, subjectivity=0.9500000000000001)
# RT @naval: Technology leads society, not the other way around. And tech comes from science &amp; math. New scientific breakthroughs lead to new…
# Sentiment(polarity=0.005681818181818177, subjectivity=0.4147727272727273)
# RT @naval: Tonight: Crypto dinner followed by crypto brainstorm w/ a friend. Called an Uber and it turned out to be @Crypto_Cab ! Glitch in…
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '881138320943828995-VshQkZGG65yykAE8NfDzKwPviR7BxZm'},
#  'resources': {'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371}},
#   'account_activity': {'/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1503899371}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1503899371}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371}},
#   'blocks': {'/blocks/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371}},
#   'collections': {'/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371},
#    '/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371}},
#   'contacts': {'/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1503899371},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371}},
#   'direct_messages': {'/direct_messages': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371},
#    '/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371}},
#   'drafts': {'/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371},
#    '/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1503899371}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371}},
#   'feedback': {'/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371},
#    '/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'friendships': {'/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1503899371},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1503899371}},
#   'geo': {'/geo/id/:place_id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1503899371}},
#   'help': {'/help/configuration': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1503899371},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1503899371},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1503899371},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/lists/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371}},
#   'live_event': {'/live_event/1/:id/timeline': {'limit': 5000,
#     'remaining': 5000,
#     'reset': 1503899371}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1503899371}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1503899371}},
#   'moments': {'/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1503899371}},
#   'mutes': {'/mutes/users/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1503899371}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 50,
#     'remaining': 50,
#     'reset': 1503899371}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 179,
#     'reset': 1503899296}},
#   'statuses': {'/statuses/friends': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1503899371},
#    '/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1503899371}},
#   'trends': {'/trends/available': {'limit': 75,
#     'remaining': 75,
#     'reset': 1503899371},
#    '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1503899371},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1503899371}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371}},
#   'users': {'/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1503899371},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1503899371},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1503899371},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1503899371},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1503899371},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371}},
#   'webhooks': {'/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371},
#    '/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1503899371}}}}
